# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd                  #data processing e.g. reading files (pd.read_csv)
import numpy as np                   #linear algebra
import matplotlib.pyplot as plt      #plotting and visualization
import seaborn as sns                #visualization
import nltk
from nltk.corpus import stopwords
import requests
import warnings
import re 
from textblob import TextBlob 
from collections import Counter
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = 8,4


# %matplotlib inline

# %%
html1 = urlopen("https://www.yelp.com/search?find_desc=Restraunts%20&find_loc=nyc")
bsObj1 = BeautifulSoup(html1)

# %%
#Get the Names Gyms
nameList = bsObj1.find_all('div', {'class': 'lemon--div__373c0__1mboc businessName__373c0__1fTgn border-color--default__373c0__2oFDT'})
for name in nameList:
    print(name.get_text())
# Out:
# Sugardaddy’s Gentlemen’s Club
# 1. Upstate
# 2. Amélie
# 3. Covenhoven
# 4. Uglyduckling
# 5. Clinton Street Baking Company
# 6. Barn Joo 35
# 7. Savida
# 8. LoveMama
# 9. Joe’s Shanghai
# 10. Raku

# %%
# Reviews
urls = []
c = 120
for i in range(12): 
    new = "https://www.yelp.com/biz/eleven-madison-park-new-york?start="+str(c)+"&sort_by=date_desc"
    urls.append(new)
    c+=20
Reviews_mad = []
for url in urls:
    html = urlopen(url)
    bsObj4 = BeautifulSoup(html)
   
    reviewers = bsObj4.find_all('div', {'itemprop': 'review'})
    for name in reviewers:
        Reviews_mad.append(name.get_text())

# %%
date_mad = []
Ratings_mad = []
for url in urls:
    html = urlopen(url)
    bsObj4 = BeautifulSoup(html)
    for name in bsObj4.find_all('meta', {'itemprop': 'datePublished'}):
        date_mad.append(name.get("content"))
    for reviewBody in bsObj4.findAll('div',{"class":"review-content"}):
        Ratings_mad.append(reviewBody.div.div.div.get("title"))

# %%
#ratings 
Ratings_mad = []

for url in urls:
    html = urlopen(url)
    bsObj4 = BeautifulSoup(html)
    for reviewBody in bsObj4.findAll('div',{"class":"review-content"}):
        Ratings_mad.append(reviewBody.div.div.div.get("title"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-207485140055> in <module>()
#       3
#       4 for url in urls:
# ----> 5     html = urlopen(url)
#       6     bsObj4 = BeautifulSoup(html)
#       7     for reviewBody in bsObj4.findAll('div',{"class":"review-content"}):
#
# /anaconda/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /anaconda/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# /anaconda/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# /anaconda/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /anaconda/lib/python3.6/urllib/request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# /anaconda/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
# -> 1321             r = h.getresponse()
#    1322         except:
#    1323             h.close()
#
# /anaconda/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /anaconda/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /anaconda/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /anaconda/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /anaconda/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1000                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1001                   self.__class__)
# -> 1002             return self.read(nbytes, buffer)
#    1003         else:
#    1004             return socket.recv_into(self, buffer, nbytes, flags)
#
# /anaconda/lib/python3.6/ssl.py in read(self, len, buffer)
#     863             raise ValueError("Read on closed or unwrapped SSL socket.")
#     864         try:
# --> 865             return self._sslobj.read(len, buffer)
#     866         except SSLError as x:
#     867             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /anaconda/lib/python3.6/ssl.py in read(self, len, buffer)
#     623         """
#     624         if buffer is not None:
# --> 625             v = self._sslobj.read(len, buffer)
#     626         else:
#     627             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
print(len(Ratings_mad))
# Out:
# 240

# %%
print(len(Reviews_mad))
# Out:
# 240

# %%
print(len(date_mad))
# Out:
# 240

# %%
yelp_data = pd.DataFrame({'Review': Reviews_mad,'Rating':Ratings_mad, 'Date': date_mad})

# %%
yelp_data['Review'] = [i.replace('\n', '') for i in yelp_data['Review']]
yelp_data['Rating'] = [float(re.sub(r'[^\d.]+','', i)) for i in yelp_data['Rating']]
yelp_data["Date"] = [pd.to_datetime(i) for i in yelp_data["Date"]]

# %%
yelp_data.to_csv("yelp_data.csv")

# %%
#sentiment analysis 
def review_sentiment(review): 
    analysis = TextBlob(review) 
    return analysis.sentiment.polarity

# %%
sentiment_list = []
for review in yelp_data['Review']:
    sentiment_list.append(review_sentiment(review))
for sent in sentiment_list:
    yelp_data["Sentiment"] = [i for i in sentiment_list]

# %%
yelp_data.head(5)
# Out:
#         Date Rating                                             Review  \
# 0 2018-11-15    4.0  If second time is the charm then our dinner on...
# 1 2018-11-14    4.0  Very good.  But I guess with all the hype, I w...
# 2 2018-11-14    5.0  This has been on my bucket list for a while bu...
# 3 2018-11-12    5.0  My boyfriend and I had an amazing experience a...
# 4 2018-11-11    5.0  Ok where do I start I think if you reserved th...
#
#    Sentiment
# 0   0.337662
# 1   0.285833
# 2   0.108203
# 3   0.110115
# 4   0.224017

# %%
fig, ax = plt.subplots(figsize = (30,10))
plt.plot(yelp_data['Date'],yelp_data['Sentiment'])
FMT = DateFormatter("%m/%d") 
ax.xaxis.set_major_formatter(FMT) 
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%y'))
plt.gca().xaxis.set_major_locator(mdates.WeekdayLocator( interval=2))

# %%
fig, ax = plt.subplots(figsize = (30,10))
plt.plot(yelp_data['Date'],yelp_data['Rating'])
FMT = DateFormatter("%m/%d") 
ax.xaxis.set_major_formatter(FMT) 
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%y'))
plt.gca().xaxis.set_major_locator(mdates.WeekdayLocator( interval=2))

# %%
groups = yelp_data.groupby(yelp_data['Date'])
yelp_data_ave_date = []
yelp_data_ave_rating = []
for i in yelp_data['Date'].unique():
    yelp_data_ave_date.append(i)
    yelp_data_ave_rating.append(np.mean(groups.get_group(i)['Rating']))
    print(groups.get_group(i))
    print(np.mean(groups.get_group(i)['Rating']))
# Out:
#         Date  Rating                                             Review  \
# 0 2018-11-15     4.0  If second time is the charm then our dinner on...
#
#    Sentiment
# 0   0.337662
# 4.0
#         Date  Rating                                             Review  \
# 1 2018-11-14     4.0  Very good.  But I guess with all the hype, I w...
# 2 2018-11-14     5.0  This has been on my bucket list for a while bu...
#
#    Sentiment
# 1   0.285833
# 2   0.108203
# 4.5
#         Date  Rating                                             Review  \
# 3 2018-11-12     5.0  My boyfriend and I had an amazing experience a...
#
#    Sentiment
# 3   0.110115
# 5.0
#         Date  Rating                                             Review  \
# 4 2018-11-11     5.0  Ok where do I start I think if you reserved th...
# 5 2018-11-11     4.0  Outstanding dining experience at Eleven Madiso...
# 6 2018-11-11     3.0  The food other than the dessert was mostly gre...
#
#    Sentiment
# 4   0.224017
# 5   0.500000
# 6   0.070536
# 4.0
#         Date  Rating                                             Review  \
# 7 2018-11-10     3.0  Ok, if this was just another regular ole resta...
# 8 2018-11-10     3.0  Disappointing. Can't believe this was #1 (and ...
#
#    Sentiment
# 7   0.215085
# 8   0.081944
# 3.0
#         Date  Rating                                             Review  \
# 9 2018-11-06     5.0  Loved came with a hot escort and had champagne...
#
#    Sentiment
# 9    0.10625
# 5.0
#          Date  Rating                                             Review  \
# 10 2018-11-05     2.0  Was treated to a meal here by a friend and the...
#
#     Sentiment
# 10   0.178132
# 2.0
#          Date  Rating                                             Review  \
# 11 2018-11-03     4.0  I had lunch here in July, it was my third time...
#
#     Sentiment
# 11   0.269792
# 4.0
#          Date  Rating                                             Review  \
# 12 2018-11-02     5.0  I came here for a birthday dinner and everythi...
#
#     Sentiment
# 12   0.504167
# 5.0
#          Date  Rating                                             Review  \
# 13 2018-10-21     2.0  Me and my wife travel a lot and have been to m...
#
#     Sentiment
# 13   0.168333
# 2.0
#          Date  Rating                                             Review  \
# 14 2018-10-16     5.0  Eleven Madison park has now become my favorite...
#
#     Sentiment
# 14   0.407476
# 5.0
#          Date  Rating                                             Review  \
# 15 2018-10-15     5.0  From our experience at my recent 21st wed anni...
#
#     Sentiment
# 15   0.246875
# 5.0
#          Date  Rating                                             Review  \
# 16 2018-10-14     5.0  EMP had been on our radar for several years an...
#
#     Sentiment
# 16   0.267964
# 5.0
#          Date  Rating                                             Review  \
# 17 2018-10-09     5.0  Eleven Madison Park was on my friend's bucket ...
#
#     Sentiment
# 17   0.336352
# 5.0
#          Date  Rating                                             Review  \
# 18 2018-10-06     3.0  Overrated! Every dish is over salted, and they...
#
#     Sentiment
# 18      -0.11
# 3.0
#          Date  Rating                                             Review  \
# 19 2018-10-04     2.0  I've been holding off on writing this review a...
#
#     Sentiment
# 19   0.018839
# 2.0
#          Date  Rating                                             Review  \
# 20 2018-09-30     5.0  This place is a dream! One of the best restaur...
# 21 2018-09-30     4.0  Quite a belated review, as I dined here in Mar...
# 22 2018-09-30     2.0  We have been there twice and its not a memorab...
#
#     Sentiment
# 20   0.950000
# 21   0.226806
# 22   0.000000
# 3.6666666666666665
#          Date  Rating                                             Review  \
# 23 2018-09-29     5.0  The mixologist is on point, the staff is extre...
#
#     Sentiment
# 23    -0.0625
# 5.0
#          Date  Rating                                             Review  \
# 24 2018-09-25     4.0  Good meal. I enjoyed some of the dishes but, o...
#
#     Sentiment
# 24   0.289286
# 4.0
#          Date  Rating                                             Review  \
# 25 2018-09-24     4.0  Looking at the past couple of year's photos/me...
# 26 2018-09-24     4.0  Checked into this high end restaurant in SOHO ...
#
#     Sentiment
# 25   0.246312
# 26   0.371250
# 4.0
#          Date  Rating                                             Review  \
# 27 2018-09-20     4.0  My friend and I had dinner at Eleven Madison P...
#
#     Sentiment
# 27    0.32849
# 4.0
#          Date  Rating                                             Review  \
# 28 2018-09-18     5.0  More than anticipated. Very comfortable atmosp...
#
#     Sentiment
# 28   0.467564
# 5.0
#          Date  Rating                                             Review  \
# 29 2018-09-17     3.0  Reading some of these detailed reviews, I woul...
#
#     Sentiment
# 29   0.444386
# 3.0
#          Date  Rating                                             Review  \
# 30 2018-09-16     1.0  The price they asking is just outrageous consi...
# 31 2018-09-16     2.0  VERY BAD SERVICE. I went to EMP two years ago ...
#
#     Sentiment
# 30   0.252500
# 31  -0.060158
# 1.5
#          Date  Rating                                             Review  \
# 32 2018-09-15     5.0  Dining at Eleven Madison Park was truly worth ...
#
#     Sentiment
# 32   0.532418
# 5.0
#          Date  Rating                                             Review  \
# 33 2018-09-14     1.0  **first time reviewer, i only created an accou...
#
#     Sentiment
# 33    0.35558
# 1.0
#          Date  Rating                                             Review  \
# 34 2018-09-12     5.0  Came here for my birthday last year around Mar...
#
#     Sentiment
# 34    0.22381
# 5.0
#          Date  Rating                                             Review  \
# 35 2018-09-08     5.0  I wish I could give 6 stars!!!  We had an inti...
#
#     Sentiment
# 35   0.265909
# 5.0
#          Date  Rating                                             Review  \
# 36 2018-09-07     4.0  Being a former ranked "best restaurant in the ...
# 37 2018-09-07     5.0  From beginning to end this place makes you fee...
# 38 2018-09-07     5.0  A restaurant and meal as elaborate as this des...
#
#     Sentiment
# 36   0.160642
# 37   0.458333
# 38   0.149405
# 4.666666666666667
#          Date  Rating                                             Review  \
# 39 2018-09-06     2.0  Honestly.......not great. I have eaten at many...
#
#     Sentiment
# 39   0.166975
# 2.0
#          Date  Rating                                             Review  \
# 40 2018-08-31     3.0  Well... I really wanted to go here for the lon...
#
#     Sentiment
# 40   0.192857
# 3.0
#          Date  Rating                                             Review  \
# 41 2018-08-30     5.0  A real experience. Amazing service, the food w...
#
#     Sentiment
# 41   0.326885
# 5.0
#          Date  Rating                                             Review  \
# 42 2018-08-28     5.0  This is an elegant restaurant. I'm not sure wh...
#
#     Sentiment
# 42   0.231633
# 5.0
#          Date  Rating                                             Review  \
# 43 2018-08-24     4.0  The service and the presentation of the dishes...
# 44 2018-08-24     5.0  This is just one of those places you have to e...
#
#     Sentiment
# 43   0.281667
# 44   0.483333
# 4.5
#          Date  Rating                                             Review  \
# 45 2018-08-23     5.0  Elegant gourmet restaurant that provides guest...
# 46 2018-08-23     2.0  Sigh.  I came here again after a few years and...
#
#     Sentiment
# 45   0.283412
# 46  -0.266667
# 3.5
#          Date  Rating                                             Review  \
# 47 2018-08-22     5.0  Flew to New York as a surprise anniversary gif...
#
#     Sentiment
# 47   0.391424
# 5.0
#          Date  Rating                                             Review  \
# 48 2018-08-16     1.0  I have been left with no choice but to leave a...
#
#     Sentiment
# 48   0.015942
# 1.0
#          Date  Rating                                             Review  \
# 49 2018-08-15     5.0  One on my best dining experiences this year at...
#
#     Sentiment
# 49   0.466213
# 5.0
#          Date  Rating                                             Review  \
# 50 2018-08-11     4.0  The service is amazing. The food is a new expe...
# 51 2018-08-11     5.0  The most unbelievable experience I've ever had...
#
#     Sentiment
# 50   0.208502
# 51   0.475556
# 4.5
#          Date  Rating                                             Review  \
# 52 2018-08-10     4.0  My dad saw that this restaurant was considered...
#
#     Sentiment
# 52   0.280273
# 4.0
#          Date  Rating                                             Review  \
# 53 2018-08-09     4.0  We went for a corporate event. I have lots of ...
#
#     Sentiment
# 53   0.370128
# 4.0
#          Date  Rating                                             Review  \
# 54 2018-08-08     3.0  Service was great but the food was too salty. ...
#
#     Sentiment
# 54        0.6
# 3.0
#          Date  Rating                                             Review  \
# 55 2018-08-07     4.0  I've had one good and one bad experience, aver...
# 56 2018-08-07     5.0  As a former best restaurant in the world winne...
#
#     Sentiment
# 55   0.160044
# 56   0.230540
# 4.5
#          Date  Rating                                             Review  \
# 57 2018-08-06     5.0  This was an amazing experience in food and art...
#
#     Sentiment
# 57   0.308544
# 5.0
#          Date  Rating                                             Review  \
# 58 2018-08-05     5.0  Had an incredible experience here! We came for...
#
#     Sentiment
# 58   0.294445
# 5.0
#          Date  Rating                                             Review  \
# 59 2018-07-31     5.0  The cuisine and attention to detail were amazi...
#
#     Sentiment
# 59    0.27504
# 5.0
#          Date  Rating                                             Review  \
# 60 2018-07-30     5.0  The most amazing experience from even before m...
#
#     Sentiment
# 60   0.443182
# 5.0
#          Date  Rating                                             Review  \
# 61 2018-07-28     5.0  Flavor packed in every bite, excellent service...
#
#     Sentiment
# 61   0.433333
# 5.0
#          Date  Rating                                             Review  \
# 62 2018-07-19     2.0  It is fine, but it is not worth the expense in...
# 63 2018-07-19     5.0  If you're going to splurge this is definitely ...
# 64 2018-07-19     5.0  Been around the block a time or two. And, this...
#
#     Sentiment
# 62   0.360606
# 63   0.332540
# 64   0.534091
# 4.0
#          Date  Rating                                             Review  \
# 65 2018-07-16     5.0  Just wow.I've been in the hospitality industry...
#
#     Sentiment
# 65   0.348756
# 5.0
#          Date  Rating                                             Review  \
# 66 2018-07-15     3.0  I went to EMP to celebrate my birthday but it ...
#
#     Sentiment
# 66   0.270969
# 3.0
#          Date  Rating                                             Review  \
# 67 2018-07-12     5.0  I held off on writing this review for 2 months...
#
#     Sentiment
# 67   0.345655
# 5.0
#          Date  Rating                                             Review  \
# 68 2018-07-11     4.0  As a foodie this is probably one of those must...
#
#     Sentiment
# 68   0.410455
# 4.0
#          Date  Rating                                             Review  \
# 69 2018-07-09     5.0  Great place to enjoy great company with excell...
#
#     Sentiment
# 69        0.7
# 5.0
#          Date  Rating                                             Review  \
# 70 2018-07-07     5.0  This was one of my favorite tasting menu exper...
# 71 2018-07-07     5.0  Not much else to add beyond the glowing review...
#
#     Sentiment
# 70    0.46713
# 71    0.10000
# 5.0
#          Date  Rating                                             Review  \
# 72 2018-07-06     5.0  Great place to splurge or celebrate a special ...
# 73 2018-07-06     2.0  I've been to a lot of fine dining restaurants ...
#
#     Sentiment
# 72   0.257540
# 73  -0.016875
# 3.5
#          Date  Rating                                             Review  \
# 74 2018-07-02     4.0  We came here for dinner this past weekend. It ...
#
#     Sentiment
# 74   0.209888
# 4.0
#          Date  Rating                                             Review  \
# 75 2018-07-01     5.0  Definitely deserving of all three stars. Staff...
# 76 2018-07-01     5.0  Excellent food and service without a strict dr...
#
#     Sentiment
# 75       0.25
# 76       0.75
# 5.0
#          Date  Rating                                             Review  \
# 77 2018-06-29     5.0  I have been fortunate enough to dine at Eleven...
#
#     Sentiment
# 77   0.301515
# 5.0
#          Date  Rating                                             Review  \
# 78 2018-06-28     5.0  Ethereal.  Have the good fortune to have been ...
# 79 2018-06-28     5.0  Beautiful place. Great food. The staff is amaz...
#
#     Sentiment
# 78    0.63750
# 79    0.68457
# 5.0
#          Date  Rating                                             Review  \
# 80 2018-06-27     5.0  This place has amazing service and food that a...
#
#     Sentiment
# 80      0.375
# 5.0
#          Date  Rating                                             Review  \
# 81 2018-06-26     5.0  My wife and I had the Dining Room Tasting Menu...
#
#     Sentiment
# 81    0.17684
# 5.0
#          Date  Rating                                             Review  \
# 82 2018-06-24     5.0  So hard to get into, but so worth the drama an...
# 83 2018-06-24     3.0  Every dish was too salty for me, even the ice ...
# 84 2018-06-24     5.0  In one word. Perfection. I was surprised with ...
#
#     Sentiment
# 82   0.225303
# 83  -0.066667
# 84   0.332500
# 4.333333333333333
#          Date  Rating                                             Review  \
# 85 2018-06-22     4.0  This place has plenty of people who work here....
#
#     Sentiment
# 85   0.216026
# 4.0
#          Date  Rating                                             Review  \
# 86 2018-06-20     5.0  Wow wow wow, what a place. The food is out of ...
#
#     Sentiment
# 86       0.26
# 5.0
#          Date  Rating                                             Review  \
# 87 2018-06-18     2.0  Finally we have decided to try out this claime...
#
#     Sentiment
# 87    -0.1865
# 2.0
#          Date  Rating                                             Review  \
# 88 2018-06-15     5.0  The spring/summer menu heavily features season...
# 89 2018-06-15     2.0  After 4+ years of living in New York and count...
#
#     Sentiment
# 88   0.276786
# 89   0.064525
# 3.5
#          Date  Rating                                             Review  \
# 90 2018-06-14     5.0  Best dining experience!! 5 star service from b...
#
#     Sentiment
# 90   0.729167
# 5.0
#          Date  Rating                                             Review  \
# 91 2018-06-13     5.0  There isn't much more that can be added - Elev...
#
#     Sentiment
# 91        0.4
# 5.0
#          Date  Rating                                             Review  \
# 92 2018-06-11     5.0  I was there in 2016 and it was my first three ...
#
#     Sentiment
# 92    0.59375
# 5.0
#          Date  Rating                                             Review  \
# 93 2018-06-10     5.0  We dined at EMP tonight to celebrate a birthda...
#
#     Sentiment
# 93   0.491004
# 5.0
#          Date  Rating                                             Review  \
# 94 2018-06-05     5.0  Went for a drink in the bar/lounge area tonigh...
#
#     Sentiment
# 94   0.594444
# 5.0
#          Date  Rating                                             Review  \
# 95 2018-06-04     2.0  Bland, everything about this restaurant is bla...
# 96 2018-06-04     4.0  Truly lived up to all the hype. Almost everyth...
# 97 2018-06-04     4.0  2 star food, 3 star service, 4 star pricingI b...
#
#     Sentiment
# 95   0.008347
# 96   0.305556
# 97   0.177551
# 3.3333333333333335
#          Date  Rating                                             Review  \
# 98 2018-06-02     5.0  Fabulous fabulous dinner! We went there with m...
# 99 2018-06-02     3.0  Eleven Madison Park pre-renovation used to be ...
#
#     Sentiment
# 98   0.450000
# 99   0.149185
# 4.0
#           Date  Rating                                             Review  \
# 100 2018-05-31     3.0  I honestly can't write an in-depth description...
#
#      Sentiment
# 100   0.014881
# 3.0
#           Date  Rating                                             Review  \
# 101 2018-05-28     5.0  At the risk of sounding Pollyanna-ish and addi...
#
#      Sentiment
# 101        0.5
# 5.0
#           Date  Rating                                             Review  \
# 102 2018-05-27     4.0  Perhaps my anticipation for the meal got the b...
# 103 2018-05-27     5.0  Incredible, truly a treasured experience when ...
# 104 2018-05-27     5.0  Can anyone give Eleven Madison Park less than ...
#
#      Sentiment
# 102   0.176696
# 103   0.758333
# 104   0.270370
# 4.666666666666667
#           Date  Rating                                             Review  \
# 105 2018-05-25     3.0  Very disappointed! I thought it would be the b...
#
#      Sentiment
# 105     0.3975
# 3.0
#           Date  Rating                                             Review  \
# 106 2018-05-24     1.0  Before I start I want to put out there that I ...
#
#      Sentiment
# 106   0.204374
# 1.0
#           Date  Rating                                             Review  \
# 107 2018-05-23     5.0  Best meal ever, best service ever, best way to...
#
#      Sentiment
# 107   0.627684
# 5.0
#           Date  Rating                                             Review  \
# 108 2018-05-12     4.0  A second visit on a beautiful spring day revea...
#
#      Sentiment
# 108   0.308333
# 4.0
#           Date  Rating                                             Review  \
# 109 2018-05-11     5.0  This is actually one of my first fine dining e...
# 110 2018-05-11     5.0  I hosted a couple of clients at Eleven Madison...
#
#      Sentiment
# 109   0.343056
# 110   0.464683
# 5.0
#           Date  Rating                                             Review  \
# 111 2018-05-10     5.0  The setting is beautiful and the presentation ...
# 112 2018-05-10     5.0  Exceptional. Ranks with the best we have done ...
#
#      Sentiment
# 111   0.538906
# 112   0.395238
# 5.0
#           Date  Rating                                             Review  \
# 113 2018-05-09     5.0  I mean come on... anyone that has given Eleven...
#
#      Sentiment
# 113   0.290648
# 5.0
#           Date  Rating                                             Review  \
# 114 2018-05-07     5.0  We came here for our first visit a few weeks a...
# 115 2018-05-07     4.0  TLDR: worth checking out for the experience, b...
#
#      Sentiment
# 114   0.318421
# 115   0.232915
# 4.5
#           Date  Rating                                             Review  \
# 116 2018-05-06     1.0  Sadly far from world number 1. The only restau...
#
#      Sentiment
# 116      0.285
# 1.0
#           Date  Rating                                             Review  \
# 117 2018-05-04     5.0  This is a review from when I had the opportuni...
# 118 2018-05-04     3.0  The atmosphere, location, and service were exa...
#
#      Sentiment
# 117   0.259619
# 118   0.008750
# 4.0
#           Date  Rating                                             Review  \
# 119 2018-05-02     5.0  A somewhat belated review of a truly memorable...
# 120 2018-05-02     4.0  Had our anniversary dinner at EMP last night. ...
#
#      Sentiment
# 119   0.192576
# 120   0.293452
# 4.5
#           Date  Rating                                             Review  \
# 121 2018-05-01     5.0  This review is pretty delayed, but that doesn'...
# 122 2018-05-01     2.0  I dined here with a friend and we both found i...
#
#      Sentiment
# 121   0.492857
# 122   0.158333
# 3.5
#           Date  Rating                                             Review  \
# 123 2018-04-29     3.0  I didn't love it here as much as I wanted to. ...
#
#      Sentiment
# 123   0.372436
# 3.0
#           Date  Rating                                             Review  \
# 124 2018-04-26     5.0  There's a reason why EMP was rated the number ...
#
#      Sentiment
# 124   0.492857
# 5.0
#           Date  Rating                                             Review  \
# 125 2018-04-24     4.0  Went on a Saturday for a 9:45pm reservation. T...
#
#      Sentiment
# 125   0.315071
# 4.0
#           Date  Rating                                             Review  \
# 126 2018-04-23     5.0  We celebrated our anniversary here, an incredi...
# 127 2018-04-23     3.0  The reputation of Eleven Madison created such ...
#
#      Sentiment
# 126   0.380438
# 127   0.235790
# 4.0
#           Date  Rating                                             Review  \
# 128 2018-04-22     5.0  The most unique food experience. The food was ...
#
#      Sentiment
# 128   0.548214
# 5.0
#           Date  Rating                                             Review  \
# 129 2018-04-21     5.0  We went for our anniversary. I was a bit conce...
# 130 2018-04-21     5.0  Eleven Madison is a true culinary experience!I...
#
#      Sentiment
# 129   0.379714
# 130   0.272917
# 5.0
#           Date  Rating                                             Review  \
# 131 2018-04-19     4.0  The first time we went to EMP last year (short...
#
#      Sentiment
# 131   0.315917
# 4.0
#           Date  Rating                                             Review  \
# 132 2018-04-16     3.0  We had a lovely time. Staff was beyond friendl...
# 133 2018-04-16     4.0  Servers and hosts were amazing and personable....
#
#      Sentiment
# 132   0.207125
# 133   0.398205
# 3.5
#           Date  Rating                                             Review  \
# 134 2018-04-14     5.0  Pretty expensive but how delicious! This place...
#
#      Sentiment
# 134   0.419589
# 5.0
#           Date  Rating                                             Review  \
# 135 2018-04-12     4.0  Took my fiancé for her birthday and let me jus...
#
#      Sentiment
# 135   0.616667
# 4.0
#           Date  Rating                                             Review  \
# 136 2018-04-11     5.0  I am a huge fan of Chef Daniel Humm and has vi...
#
#      Sentiment
# 136   0.436958
# 5.0
#           Date  Rating                                             Review  \
# 137 2018-04-10     5.0  A truly special experience and one of the best...
#
#      Sentiment
# 137    0.30119
# 5.0
#           Date  Rating                                             Review  \
# 138 2018-04-06     4.0  Great Michelin 3-star restaurant. My family an...
#
#      Sentiment
# 138   0.342208
# 4.0
#           Date  Rating                                             Review  \
# 139 2018-04-05     5.0  What a fun experience! We came here for our an...
#
#      Sentiment
# 139    0.68125
# 5.0
#           Date  Rating                                             Review  \
# 140 2018-04-04     5.0  Had the bar menu and it was exquisite.  Hubby ...
# 141 2018-04-04     5.0  Eleven Madison Park is one of the strongest pi...
#
#      Sentiment
# 140   0.319722
# 141   0.423918
# 5.0
#           Date  Rating                                             Review  \
# 142 2018-04-01     2.0  We came here on probably one of the coldest ni...
#
#      Sentiment
# 142  -0.020119
# 2.0
#           Date  Rating                                             Review  \
# 143 2018-03-31     5.0  Contemporary American restaurant. Favorite dis...
#
#      Sentiment
# 143   0.378158
# 5.0
#           Date  Rating                                             Review  \
# 144 2018-03-26     5.0  We went here for lunch.  It was an unique dini...
# 145 2018-03-26     5.0  Hands down best 3 star restaurant I've been to...
#
#      Sentiment
# 144   0.512500
# 145   0.282354
# 5.0
#           Date  Rating                                             Review  \
# 146 2018-03-25     5.0  I went here for a lunch service prior to the r...
# 147 2018-03-25     4.0  1 to 10FOOD : 7.5 Simple and nice, for my tast...
#
#      Sentiment
# 146   0.168294
# 147   0.152674
# 4.5
#           Date  Rating                                             Review  \
# 148 2018-03-13     5.0  Gorgeous creations. Delightful appetizers. Gra...
#
#      Sentiment
# 148       0.77
# 5.0
#           Date  Rating                                             Review  \
# 149 2018-03-10     2.0  Dined at EMP in December 2017 and I have to sa...
#
#      Sentiment
# 149   0.251563
# 2.0
#           Date  Rating                                             Review  \
# 150 2018-03-08     5.0  From beginning to end it was worth every singl...
# 151 2018-03-08     3.0  I had such high hopes for this restaurant. My ...
#
#      Sentiment
# 150   0.242857
# 151   0.236136
# 4.0
#           Date  Rating                                             Review  \
# 152 2018-03-07     5.0  I have chosen this restaurant for the special ...
# 153 2018-03-07     4.0  Food 4 starsHad higher expectations on it,desp...
# 154 2018-03-07     4.0  Had the tasting 5 course tasting menu.   It wa...
#
#      Sentiment
# 152   0.382857
# 153   0.510000
# 154   0.266667
# 4.333333333333333
#           Date  Rating                                             Review  \
# 155 2018-03-06     5.0  Went here because the gentlemen in charge of t...
#
#      Sentiment
# 155       0.54
# 5.0
#           Date  Rating                                             Review  \
# 156 2018-03-05     4.0  So this restaurant is definitely up there in m...
#
#      Sentiment
# 156   0.232251
# 4.0
#           Date  Rating                                             Review  \
# 157 2018-03-03     5.0  Excellent service - despite our large party - ...
#
#      Sentiment
# 157   0.524524
# 5.0
#           Date  Rating                                             Review  \
# 158 2018-02-27     2.0  toooooo salty. Came here with friends for my b...
#
#      Sentiment
# 158       0.05
# 2.0
#           Date  Rating                                             Review  \
# 159 2018-02-26     4.0  I really want to do justice to this amazing ex...
# 160 2018-02-26     4.0  Dinner was great, but a bit lackluster for the...
#
#      Sentiment
# 159   0.336112
# 160   0.485000
# 4.0
#           Date  Rating                                             Review  \
# 161 2018-02-21     3.0  Maybe it was the hype of going to the # 1 rate...
# 162 2018-02-21     5.0  I visited this restaurant with a friend (VF) t...
#
#      Sentiment
# 161   0.327976
# 162   0.236667
# 4.0
#           Date  Rating                                             Review  \
# 163 2018-02-19     4.0  I come here to celebrate my birthday. "The Bes...
#
#      Sentiment
# 163   0.170208
# 4.0
#           Date  Rating                                             Review  \
# 164 2018-02-18     1.0  If you plan on dining at the No.1 restaurant i...
#
#      Sentiment
# 164   0.024478
# 1.0
#           Date  Rating                                             Review  \
# 165 2018-02-13     5.0  There are not enough words to describe EMP but...
# 166 2018-02-13     5.0  This is the best meal I've ever had in my life...
#
#      Sentiment
# 165   0.256388
# 166   0.466667
# 5.0
#           Date  Rating                                             Review  \
# 167 2018-02-12     5.0  EMP will forever be the GOAT of food and dinin...
#
#      Sentiment
# 167   0.358929
# 5.0
#           Date  Rating                                             Review  \
# 168 2018-02-11     1.0  Well, what can I say... Michelin Guide is very...
#
#      Sentiment
# 168   0.092658
# 1.0
#           Date  Rating                                             Review  \
# 169 2018-02-10     4.0  Eleven Madison Park, led by Daniel Humm and Wi...
# 170 2018-02-10     5.0  Lives up to the expectations of a three star M...
#
#      Sentiment
# 169   0.217235
# 170   0.309479
# 4.5
#           Date  Rating                                             Review  \
# 171 2018-02-08     5.0  Definitely lives up to its reputation as the b...
#
#      Sentiment
# 171   0.352431
# 5.0
#           Date  Rating                                             Review  \
# 172 2018-02-05     4.0  Very cerebral and interactive dining experienc...
# 173 2018-02-05     2.0  Didn't live up to hype. Food was unusually sal...
#
#      Sentiment
# 172   0.360256
# 173   0.327670
# 3.0
#           Date  Rating                                             Review  \
# 174 2018-01-30     3.0  Skip it. For the pre-fix edible artwork. Every...
# 175 2018-01-30     5.0  Not really much I can add here, except that th...
#
#      Sentiment
# 174      -0.15
# 175       0.22
# 4.0
#           Date  Rating                                             Review  \
# 176 2018-01-29     3.0  I have been here 6 times and i only loved it o...
#
#      Sentiment
# 176  -0.017857
# 3.0
#           Date  Rating                                             Review  \
# 177 2018-01-28     4.0  Great dining experience. Good service with a g...
#
#      Sentiment
# 177   0.552679
# 4.0
#           Date  Rating                                             Review  \
# 178 2018-01-27     3.0  The food and presentation was excellent but I ...
# 179 2018-01-27     5.0  Amazing dining experience! The service was gre...
# 180 2018-01-27     1.0  I have to say that I was quite disappointed wi...
#
#      Sentiment
# 178   0.176015
# 179   0.382041
# 180   0.072283
# 3.0
#           Date  Rating                                             Review  \
# 181 2018-01-24     5.0  Came here to have lunch with my husband.Our ne...
#
#      Sentiment
# 181    0.37963
# 5.0
#           Date  Rating                                             Review  \
# 182 2018-01-23     4.0  Lives up to its reputations and 3 stars.  The ...
# 183 2018-01-23     5.0  This was an experience to remember. I remember...
#
#      Sentiment
# 182   0.104643
# 183   0.443095
# 4.5
#           Date  Rating                                             Review  \
# 184 2018-01-22     3.0  The best restaurant in the world - according t...
#
#      Sentiment
# 184   0.078513
# 3.0
#           Date  Rating                                             Review  \
# 185 2018-01-21     4.0  My best friend and I decided to go here since ...
# 186 2018-01-21     5.0  Young and fun--what a surprise.  It takes a na...
#
#      Sentiment
# 185   0.356621
# 186   0.290000
# 4.5
#           Date  Rating                                             Review  \
# 187 2018-01-20     5.0  Eleven Madison Park was nothing short of magic...
#
#      Sentiment
# 187   0.148885
# 5.0
#           Date  Rating                                             Review  \
# 188 2018-01-18     5.0  A wonderful foodie experience! Highly recommen...
#
#      Sentiment
# 188      0.415
# 5.0
#           Date  Rating                                             Review  \
# 189 2018-01-17     5.0  I'm not sure what there is to say that's not a...
#
#      Sentiment
# 189   0.242952
# 5.0
#           Date  Rating                                             Review  \
# 190 2018-01-16     4.0  Dinner pre fix menu is too expensive.  The foo...
#
#      Sentiment
# 190   0.155344
# 4.0
#           Date  Rating                                             Review  \
# 191 2018-01-15     3.0  Maybe because it was the "bar version" but ove...
#
#      Sentiment
# 191   0.613333
# 3.0
#           Date  Rating                                             Review  \
# 192 2018-01-12     1.0  Wow, what a night, I  left the restaurant shoc...
#
#      Sentiment
# 192   0.083904
# 1.0
#           Date  Rating                                             Review  \
# 193 2018-01-11     5.0  If Heaven has a Restaurant....Eleven Madison P...
#
#      Sentiment
# 193   0.365392
# 5.0
#           Date  Rating                                             Review  \
# 194 2018-01-10     1.0  First visit here, it was world class, one of t...
# 195 2018-01-10     4.0  After looking forward to EMP, the "world's bes...
#
#      Sentiment
# 194   0.191667
# 195   0.226361
# 2.5
#           Date  Rating                                             Review  \
# 196 2017-12-27     5.0  This experience was truly sublime. It's no won...
#
#      Sentiment
# 196    0.33993
# 5.0
#           Date  Rating                                             Review  \
# 197 2017-12-26     2.0  As many other foodies. if given a chance to ex...
#
#      Sentiment
# 197   0.097929
# 2.0
#           Date  Rating                                             Review  \
# 198 2017-12-23     3.0  The best restaurant in the world is ok. Which ...
# 199 2017-12-23     5.0  Although it has taken me over four years to wr...
#
#      Sentiment
# 198   0.223889
# 199   0.480000
# 4.0
#           Date  Rating                                             Review  \
# 200 2017-12-21     3.0  Eleven Madison Park - the world's number one r...
#
#      Sentiment
# 200   0.238535
# 3.0
#           Date  Rating                                             Review  \
# 201 2017-12-17     4.0  EMP has always been held in high regard by any...
#
#      Sentiment
# 201   0.227798
# 4.0
#           Date  Rating                                             Review  \
# 202 2017-12-11     3.0  Being the foodie that I am, I had to check out...
#
#      Sentiment
# 202   0.179092
# 3.0
#           Date  Rating                                             Review  \
# 203 2017-12-10     5.0  Certainly will go down as one of the most memo...
#
#      Sentiment
# 203   0.413591
# 5.0
#           Date  Rating                                             Review  \
# 204 2017-12-08     3.0  Service is exceptional! Waiters/waitresses are...
#
#      Sentiment
# 204   0.490076
# 3.0
#           Date  Rating                                             Review  \
# 205 2017-12-06     5.0  What a great experience! The opening truffle s...
#
#      Sentiment
# 205   0.414394
# 5.0
#           Date  Rating                                             Review  \
# 206 2017-12-03     5.0  Wow, what an honor to dine at the number one r...
#
#      Sentiment
# 206   0.314583
# 5.0
#           Date  Rating                                             Review  \
# 207 2017-12-01     5.0  Literally one of the most amazing dining exper...
#
#      Sentiment
# 207   0.304353
# 5.0
#           Date  Rating                                             Review  \
# 208 2017-11-30     5.0  I thought that no restaurant could meet the hy...
# 209 2017-11-30     3.0  The anticipation is better than the actual exp...
#
#      Sentiment
# 208   0.625000
# 209   0.147692
# 4.0
#           Date  Rating                                             Review  \
# 210 2017-11-26     2.0  Really? This restaurant is supposed to be numb...
#
#      Sentiment
# 210   0.121053
# 2.0
#           Date  Rating                                             Review  \
# 211 2017-11-25     5.0  This was one of the best meals I have had in a...
#
#      Sentiment
# 211    0.37625
# 5.0
#           Date  Rating                                             Review  \
# 212 2017-11-23     2.0  What a huge disappointment. My wife and I are ...
# 213 2017-11-23     5.0  Such an amazing experience!  I've been a few 3...
#
#      Sentiment
# 212   0.001621
# 213   0.360277
# 3.5
#           Date  Rating                                             Review  \
# 214 2017-11-21     5.0  I find it a bit ridiculous that I'm writing a ...
#
#      Sentiment
# 214   0.401852
# 5.0
#           Date  Rating                                             Review  \
# 215 2017-11-20     5.0  Best food and service stuff. Everything that I...
#
#      Sentiment
# 215    0.45625
# 5.0
#           Date  Rating                                             Review  \
# 216 2017-11-18     2.0  We're waiting for our Uber, having just had my...
#
#      Sentiment
# 216   0.068254
# 2.0
#           Date  Rating                                             Review  \
# 217 2017-11-12     5.0  We made it in for the first time before EMP cl...
#
#      Sentiment
# 217   0.193056
# 5.0
#           Date  Rating                                             Review  \
# 218 2017-11-10     5.0  The hotel has been beautifully updated and the...
#
#      Sentiment
# 218   0.488542
# 5.0
#           Date  Rating                                             Review  \
# 219 2017-11-09     5.0  Excellent. 10/10 I loved everything about my e...
# 220 2017-11-09     3.0  Have you ever walked away from a restaurant di...
#
#      Sentiment
# 219   0.540606
# 220   0.175100
# 4.0
#           Date  Rating                                             Review  \
# 221 2017-11-06     4.0  I can't believe I'm giving "The Best Restauran...
#
#      Sentiment
# 221   0.209231
# 4.0
#           Date  Rating                                             Review  \
# 222 2017-11-04     5.0  Currently, this is the best restaurant I have ...
#
#      Sentiment
# 222   0.331818
# 5.0
#           Date  Rating                                             Review  \
# 223 2017-11-03     5.0  This restaurant needs no introduction, nor doe...
#
#      Sentiment
# 223   0.249274
# 5.0
#           Date  Rating                                             Review  \
# 224 2017-11-02     4.0  Honest review from a personal point of view is...
#
#      Sentiment
# 224   0.248431
# 4.0
#           Date  Rating                                             Review  \
# 225 2017-10-30     4.0  I came to EMP on my first trip to NYC, to cele...
#
#      Sentiment
# 225   0.196442
# 4.0
#           Date  Rating                                             Review  \
# 226 2017-10-28     5.0  It earns its title as the best restaurant in t...
#
#      Sentiment
# 226   0.583333
# 5.0
#           Date  Rating                                             Review  \
# 227 2017-10-27     3.0  EMP (bar experience) was very disappointing.  ...
# 228 2017-10-27     4.0  I had been several years ago and was a bit und...
# 229 2017-10-27     1.0  Thoroughly unimpressed.  The service was atten...
#
#      Sentiment
# 227   0.220067
# 228   0.411488
# 229   0.084333
# 2.6666666666666665
#           Date  Rating                                             Review  \
# 230 2017-10-26     2.0  Overall very disappointing. when you wait at t...
#
#      Sentiment
# 230   0.122407
# 2.0
#           Date  Rating                                             Review  \
# 231 2017-10-23     3.0  I came here to celebrate my birthday.  The spa...
#
#      Sentiment
# 231   0.311364
# 3.0
#           Date  Rating                                             Review  \
# 232 2017-10-22     5.0  Impeccable dining experience at the world no. ...
#
#      Sentiment
# 232   0.376308
# 5.0
#           Date  Rating                                             Review  \
# 233 2017-10-13     3.0  I have been super excited to try EMP, especial...
#
#      Sentiment
# 233   0.338938
# 3.0
#           Date  Rating                                             Review  \
# 234 2017-10-08     5.0  Went there for hubbys  date night and was surp...
#
#      Sentiment
# 234   0.416667
# 5.0
#           Date  Rating                                             Review  \
# 235 2017-10-06     4.0  The restaurant, designed by Bentel & Bentel, i...
#
#      Sentiment
# 235    0.23915
# 4.0
#           Date  Rating                                             Review  \
# 236 2017-09-15     2.0  April 23, 201712:00 PM4 GuestsMaybe an off nig...
#
#      Sentiment
# 236   -0.06181
# 2.0
#           Date  Rating                                             Review  \
# 237 2017-08-22     4.0  Delicious food and great service!! We went the...
#
#      Sentiment
# 237   0.604167
# 4.0
#           Date  Rating                                             Review  \
# 238 2017-08-18     5.0  Professional as can be. Felt like a king being...
#
#      Sentiment
# 238   0.406667
# 5.0
#           Date  Rating                                             Review  \
# 239 2017-08-10     3.0  My boyfriend and I received a gift card to din...
#
#      Sentiment
# 239   0.197917
# 3.0

# %%
yelp_data_ave = pd.DataFrame({'Date': yelp_data_ave_date,'Average Rating':yelp_data_ave_rating})

# %%
fig, ax = plt.subplots(figsize = (30,10))
plt.plot(yelp_data_ave['Date'],yelp_data_ave['Average'])
FMT = DateFormatter("%m/%d") 
ax.xaxis.set_major_formatter(FMT) 
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%y'))
plt.gca().xaxis.set_major_locator(mdates.WeekdayLocator( interval=2))
